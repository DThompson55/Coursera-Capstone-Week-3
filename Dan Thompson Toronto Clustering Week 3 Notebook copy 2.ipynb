# %% [markdown]
# #This is the Answer to the 2nd question Week 3
# #First, import the libs we'll need. then use wget to pull down the wikipedia page about Toroto Neighborhoods

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis 
import codecs
from bs4 import BeautifulSoup

# !wget https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# Out:
# --2019-04-14 05:18:53--  https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# Resolving en.wikipedia.org (en.wikipedia.org)... 91.198.174.192, 2620:0:862:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|91.198.174.192|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 80047 (78K) [text/html]
# Saving to: ‘List_of_postal_codes_of_Canada:_M.3’
#
# 100%[======================================>] 80,047       313KB/s   in 0.2s
#
# 2019-04-14 05:18:54 (313 KB/s) - ‘List_of_postal_codes_of_Canada:_M.3’ saved [80047/80047]

# %% [markdown]
# #Now parse the neighborhood table into a string, and turn that into a DataFrame, name the columns and drop unassigned

# %%
f = codecs.open('List_of_postal_codes_of_Canada:_M', encoding='utf-8')
html = f.read()
soup = BeautifulSoup(html, 'html.parser')

df = (pd.read_html(str(soup.table))[0])

#drop the first row, which is the headings of the table
df.drop(axis=0, index=0, inplace=True)

#then assign the proper column names
column_names = ['Postcode', 'Borough', 'Neighborhood'] 
df.columns = column_names

#get rid of unassigned Boroughs
df = df[df['Borough'] != "Not assigned"].reset_index(drop=True) 
df
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M5A  Downtown Toronto
# 4        M6A        North York
# 5        M6A        North York
# 6        M7A      Queen's Park
# 7        M9A         Etobicoke
# 8        M1B       Scarborough
# 9        M1B       Scarborough
# 10       M3B        North York
# 11       M4B         East York
# 12       M4B         East York
# 13       M5B  Downtown Toronto
# 14       M5B  Downtown Toronto
# 15       M6B        North York
# 16       M9B         Etobicoke
# 17       M9B         Etobicoke
# 18       M9B         Etobicoke
# 19       M9B         Etobicoke
# 20       M9B         Etobicoke
# 21       M1C       Scarborough
# 22       M1C       Scarborough
# 23       M1C       Scarborough
# 24       M3C        North York
# 25       M3C        North York
# 26       M4C         East York
# 27       M5C  Downtown Toronto
# 28       M6C              York
# 29       M9C         Etobicoke
# ..       ...               ...
# 181      M9V         Etobicoke
# 182      M1W       Scarborough
# 183      M4W  Downtown Toronto
# 184      M5W  Downtown Toronto
# 185      M8W         Etobicoke
# 186      M8W         Etobicoke
# 187      M9W         Etobicoke
# 188      M1X       Scarborough
# 189      M4X  Downtown Toronto
# 190      M4X  Downtown Toronto
# 191      M5X  Downtown Toronto
# 192      M5X  Downtown Toronto
# 193      M8X         Etobicoke
# 194      M8X         Etobicoke
# 195      M8X         Etobicoke
# 196      M4Y  Downtown Toronto
# 197      M7Y      East Toronto
# 198      M8Y         Etobicoke
# 199      M8Y         Etobicoke
# 200      M8Y         Etobicoke
# 201      M8Y         Etobicoke
# 202      M8Y         Etobicoke
# 203      M8Y         Etobicoke
# 204      M8Y         Etobicoke
# 205      M8Y         Etobicoke
# 206      M8Z         Etobicoke
# 207      M8Z         Etobicoke
# 208      M8Z         Etobicoke
# 209      M8Z         Etobicoke
# 210      M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                                          Regent Park
# 4                                     Lawrence Heights
# 5                                       Lawrence Manor
# 6                                         Not assigned
# 7                                     Islington Avenue
# 8                                                Rouge
# 9                                              Malvern
# 10                                     Don Mills North
# 11                                    Woodbine Gardens
# 12                                       Parkview Hill
# 13                                             Ryerson
# 14                                     Garden District
# 15                                           Glencairn
# 16                                          Cloverdale
# 17                                           Islington
# 18                                        Martin Grove
# 19                                    Princess Gardens
# 20                                     West Deane Park
# 21                                      Highland Creek
# 22                                          Rouge Hill
# 23                                          Port Union
# 24                                     Flemingdon Park
# 25                                     Don Mills South
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 29                                   Bloordale Gardens
# ..                                                 ...
# 181                                        Thistletown
# 182                                    L'Amoreaux West
# 183                                           Rosedale
# 184                    Stn A PO Boxes 25 The Esplanade
# 185                                          Alderwood
# 186                                        Long Branch
# 187                                          Northwest
# 188                                        Upper Rouge
# 189                                        Cabbagetown
# 190                                     St. James Town
# 191                               First Canadian Place
# 192                                   Underground city
# 193                                       The Kingsway
# 194                                    Montgomery Road
# 195                                     Old Mill North
# 196                               Church and Wellesley
# 197  Business Reply Mail Processing Centre 969 Eastern
# 198                                         Humber Bay
# 199                                   King's Mill Park
# 200                           Kingsway Park South East
# 201                                          Mimico NE
# 202                                     Old Mill South
# 203                                 The Queensway East
# 204                              Royal York South East
# 205                                           Sunnylea
# 206                           Kingsway Park South West
# 207                                          Mimico NW
# 208                                 The Queensway West
# 209                              Royal York South West
# 210                                     South of Bloor
#
# [211 rows x 3 columns]

# %% [markdown]
# #If the neighborhood isn't assigned, make it the same as the borough name

# %%
na = df[df['Neighborhood']=="Not assigned"]
for index in range(len(na)):
    r = na.iloc[index]
    r['Neighborhood']=r['Borough']
    df.iloc[na.index[0]]['Neighborhood'] = r['Borough']

df.head(8)
# Out:
#   Postcode           Borough      Neighborhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights
# 5      M6A        North York    Lawrence Manor
# 6      M7A      Queen's Park      Queen's Park
# 7      M9A         Etobicoke  Islington Avenue

# %%
#Now get all of the unique Post codes using Groupby, then walk through that df. 
#Match the post code in the original df
#Set the Borough, and then make a list of all the neighborhoods in that postcode, format the string using join method

# %%
aggregations = {
    'Neighborhood':lambda x:', '.join(x)}
g = df.groupby('Postcode').agg(aggregations).reset_index()
x = df.drop('Neighborhood',axis=1)
m = pd.merge(x, g, on='Postcode', how='left')
dd = m.drop_duplicates()
dd
#this throws a warning but the results seem to check out
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 4        M6A        North York
# 6        M7A      Queen's Park
# 7        M9A         Etobicoke
# 8        M1B       Scarborough
# 10       M3B        North York
# 11       M4B         East York
# 13       M5B  Downtown Toronto
# 15       M6B        North York
# 16       M9B         Etobicoke
# 21       M1C       Scarborough
# 24       M3C        North York
# 26       M4C         East York
# 27       M5C  Downtown Toronto
# 28       M6C              York
# 29       M9C         Etobicoke
# 33       M1E       Scarborough
# 36       M4E      East Toronto
# 37       M5E  Downtown Toronto
# 38       M6E              York
# 39       M1G       Scarborough
# 40       M4G         East York
# 41       M5G  Downtown Toronto
# 42       M6G  Downtown Toronto
# 43       M1H       Scarborough
# 44       M2H        North York
# 45       M3H        North York
# 48       M4H         East York
# ..       ...               ...
# 130      M4R   Central Toronto
# 131      M5R   Central Toronto
# 134      M6R      West Toronto
# 136      M7R       Mississauga
# 137      M9R         Etobicoke
# 141      M1S       Scarborough
# 142      M4S   Central Toronto
# 143      M5S  Downtown Toronto
# 145      M6S      West Toronto
# 147      M1T       Scarborough
# 150      M4T   Central Toronto
# 152      M5T  Downtown Toronto
# 155      M1V       Scarborough
# 159      M4V   Central Toronto
# 164      M5V  Downtown Toronto
# 171      M8V         Etobicoke
# 174      M9V         Etobicoke
# 182      M1W       Scarborough
# 183      M4W  Downtown Toronto
# 184      M5W  Downtown Toronto
# 185      M8W         Etobicoke
# 187      M9W         Etobicoke
# 188      M1X       Scarborough
# 189      M4X  Downtown Toronto
# 191      M5X  Downtown Toronto
# 193      M8X         Etobicoke
# 196      M4Y  Downtown Toronto
# 197      M7Y      East Toronto
# 198      M8Y         Etobicoke
# 206      M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Harbourfront, Regent Park
# 4                     Lawrence Heights, Lawrence Manor
# 6                                         Queen's Park
# 7                                     Islington Avenue
# 8                                       Rouge, Malvern
# 10                                     Don Mills North
# 11                     Woodbine Gardens, Parkview Hill
# 13                            Ryerson, Garden District
# 15                                           Glencairn
# 16   Cloverdale, Islington, Martin Grove, Princess ...
# 21              Highland Creek, Rouge Hill, Port Union
# 24                    Flemingdon Park, Don Mills South
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 29   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 33                   Guildwood, Morningside, West Hill
# 36                                         The Beaches
# 37                                         Berczy Park
# 38                                 Caledonia-Fairbanks
# 39                                              Woburn
# 40                                             Leaside
# 41                                  Central Bay Street
# 42                                            Christie
# 43                                           Cedarbrae
# 44                                   Hillcrest Village
# 45     Bathurst Manor, Downsview North, Wilson Heights
# 48                                    Thorncliffe Park
# ..                                                 ...
# 130                                 North Toronto West
# 131                The Annex, North Midtown, Yorkville
# 134                             Parkdale, Roncesvalles
# 136              Canada Post Gateway Processing Centre
# 137  Kingsview Village, Martin Grove Gardens, Richv...
# 141                                          Agincourt
# 142                                         Davisville
# 143                     Harbord, University of Toronto
# 145                                 Runnymede, Swansea
# 147            Clarks Corners, Sullivan, Tam O'Shanter
# 150                        Moore Park, Summerhill East
# 152          Chinatown, Grange Park, Kensington Market
# 155  Agincourt North, L'Amoreaux East, Milliken, St...
# 159  Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 164  CN Tower, Bathurst Quay, Island airport, Harbo...
# 171       Humber Bay Shores, Mimico South, New Toronto
# 174  Albion Gardens, Beaumond Heights, Humbergate, ...
# 182                                    L'Amoreaux West
# 183                                           Rosedale
# 184                    Stn A PO Boxes 25 The Esplanade
# 185                             Alderwood, Long Branch
# 187                                          Northwest
# 188                                        Upper Rouge
# 189                        Cabbagetown, St. James Town
# 191             First Canadian Place, Underground city
# 193      The Kingsway, Montgomery Road, Old Mill North
# 196                               Church and Wellesley
# 197  Business Reply Mail Processing Centre 969 Eastern
# 198  Humber Bay, King's Mill Park, Kingsway Park So...
# 206  Kingsway Park South West, Mimico NW, The Queen...
#
# [103 rows x 3 columns]

# %% [markdown]
# #This is where the second Question Part Starts
# #start with getting the geospacial data
# #I tried doing it programatically, but it just kept looping

# %%
# !wget http://cocl.us/Geospatial_data
# Out:
# --2019-04-14 05:20:07--  http://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 169.48.113.201
# Connecting to cocl.us (cocl.us)|169.48.113.201|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data [following]
# --2019-04-14 05:20:07--  https://cocl.us/Geospatial_data
# Connecting to cocl.us (cocl.us)|169.48.113.201|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-04-14 05:20:07--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.27.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.27.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-04-14 05:20:08--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-04-14 05:20:08--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.27.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.27.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1
0Mx2jHO1kuIsHyosjPJk5TG6v-ruymTqBUcURzS4xC6IvNX5XqPPNteNIyPovA0igl6J4Q1-Gt3Ru6oy1rHP8HNz2AL3HkTkAex4pjMkZ8qm4OUynibxXrODTGyo0MQfcS6xGlUrjtaBtL_bA1UA2dJCWALHcIENsR8-b2BfGjytLgfhPXR4pzJJLnBTrGg6GgrTomub-yGiztYSvQS-Id8WE14FMsBuU4R9L3ikBk0ND-podQeQKwufzBnQBuQ8gEPx9pPynfyecBUdiCSEuvj-SyehVXKi4hhgVO0AvH2cquAgGO5964ZVD32dVm2gVnabimLO2Y4qcchaYOUwQCO1pTa_IeNWAmIZlyBv6HPGzfvRmUeqAHy3m0TNNuLkS54n31eDFl0IOKGuGHqiKIrkLBs3QpsyPV5MmvsH8yNdTC7S3_lAP0KIiUrKyilrM6lWKmRyL9EP0xW8JYd93fd6Uq9ooRvObLsdd0o4qJ_Iv4zquQNWmWlXbsoy0hWPwwdfnwhIJR1ez0vXvqV5sj7LGyV2JfqJTQF-lOVGc9PTbgwysAdTzJPaNL655sEVGzEy_ClvTWFdu1DG-l8OoVKaVV2echA666Q2CzdkWQnjLGw6OksvtYiDs05hjQtyUgRheI3BoJcHNk7YBVro6_7e42vE_XNku9ORGSbXljqolok7WuKFdJavin7OOcKe_kC2mZFje6MR2vjyxpztIVkhoG-ZJsB0p0SoqmTBEy5rNknrDjIMhi3OB8Pjfx68mTUbjBFrfmIjjt1d3KpZYt1IyP3RI5NHWXZMoHbmsDD8_an2mGX1z4fzyfa2TCMysO6ueMaiENqxkmK5sc9U9wuTSc6lGVwGSCLH0kWImpIepiRLJfpN-S7kqqEZrbFZNhf0AYFZJFv0Grt0yGEcPLoNFk8VvToNDuET61IniQu5SF26GKrIKTxNQS9VLDfp6yKRNQA_L9VFb3BZhA6sv41c9df94j0LpQ4t3kaim67rpwyt6OfY4CZanUzFyoy4VsqTB2wwJa8ZhfeccKAF1f7pv5ibcv5ue4rZwAs0tcdwXQhU-qmJv2gYWOGCdI1Ry-wwKOweFO60H-n8VLhtKlXs1cRUKy5WiY1hjL3JAfpqWY2DcBDoCDLI7c1BqzZT1DydCFUM1K8SCwR6KgeFo5EnLPWUa9HYDCld2hhzyKw_HKLyuP7te8tCWFC8ud7-I83PThw../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.27.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.27.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_data.4’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2019-04-14 05:20:09 (431 MB/s) - ‘Geospatial_data.4’ saved [2891/2891]

# %% [markdown]
# #Now that we have geo data, just read it in.
# Let's add columns for lat and long
# and then loop through the original neighborhoods data and merge in the lat/long from the geospacial data
# it throws a warning but it seems to work just fine

# %%
geo = pd.read_csv('Geospatial_data')
geo.columns = ['Postcode', 'Latitude', 'Longitude']

df_outer = pd.merge(dd, geo, on='Postcode', how='inner')
df_outer
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# ..       ...               ...
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Harbourfront, Regent Park  43.654260 -79.360636
# 3                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                         Queen's Park  43.662301 -79.389494
# 5                                     Islington Avenue  43.667856 -79.532242
# 6                                       Rouge, Malvern  43.806686 -79.194353
# 7                                      Don Mills North  43.745906 -79.352188
# 8                      Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                             Ryerson, Garden District  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 12              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 13                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# ..                                                 ...        ...        ...
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      Harbord, University of Toronto  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 85   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 88        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 90                                     L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         Cabbagetown, St. James Town  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 101  Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 102  Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# #And that's it. the output looks good and compares to the sample for Q2
